# %% [markdown]
# # Парсинг

# %%
# Необходимые импорты
import requests
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
import pandas as pd
import time

# %%
url = 'https://bolshoi.ru/timetable/all'
response = requests.get(url)                            #установление соединения с ur
                                                        # т.е. сходили к серверу, пнул и получили html
                                                        # разметку нужной нам странниц
response
# Out:
# <Response [200]>

# %%
tree = BeautifulSoup(response.content, 'html.parser')

# %%
tree
# Out:
# <!DOCTYPE html>
#
# <html data-n-head="%7B%22lang%22:%7B%22ssr%22:%22ru-RU%22%7D,%22dir%22:%7B%22ssr%22:%22ltr%22%7D%7D" data-n-head-ssr="" dir="ltr" lang="ru-RU">
# <head>
# ...

# %% [markdown]
# ___

# %% [markdown]
# Даты

# %%
data = tree.find_all('div', {'class': 'PosterCatalogItem-date'})
data[4].text
# Out:
# '19 ноября'

# %% [markdown]
# День недели

# %%
day_of_week = tree.find_all('div', {'class': 'PosterCatalogItem-day'})
day_of_week[0].text
# Out:
# 'среда'

# %% [markdown]
# Тип спектакля

# %%
performance_type = tree.find_all('div', {'class': 'PosterCard-subtitle'})
performance_type[0].text
# Out:
# 'ballet'

# %% [markdown]
# Название спектакля

# %%
performance_name = tree.find_all('div', {'class': 'PosterCard-contentWrapper'})
performance_name[7].h3.text
# Out:
# 'Адриана Лекуврёр'

# %% [markdown]
# Возрастное ограничение

# %%
performance_age = tree.find_all('div', {'class': 'PosterCard-age'})
performance_age[0].text
# Out:
# '16+'

# %% [markdown]
# Время начала представления

# %%
performance_time = tree.find_all('div', {'class': 'PosterCard-time'})
performance_time[0].text
# Out:
# '19:00'

# %% [markdown]
# Сцена

# %%
performance_scene = tree.find_all('div', {'class': 'PosterCard-sceneText'})
performance_scene[0].text
# Out:
# 'Новая сцена'

# %% [markdown]
# ___

# %%
performance_url = soup_add.find_all('div', {'class': 'PosterCard PosterCard--historical noPicture isLink'})
performance_url[0].a
# Out:
# <a class="b-hidden-link PosterCard-link" data-v-6762166a="" data-v-689ea329="" href="/performances/opera/adriana-lecouvreur"></a>

# %%
# сохраним код html страницы
page_add = br.page_source
soup_add = BeautifulSoup(page_add, 'html')
soup_add
# Out:
# <html data-n-head="%7B%22lang%22:%7B%22ssr%22:%22ru-RU%22%7D,%22dir%22:%7B%22ssr%22:%22ltr%22%7D%7D" dir="ltr" lang="ru-RU" style="--scrollbar-width: 17px;"><head>
# ...

# %%
performance_tickets = soup_add.find_all('div', {'class': 'PosterCard-tickets'})
performance_tickets[0].text
# Out:
# '40 билетов'

# %%
performance_price = soup_add.find_all('div', {'class': 'PosterCard-price'})
performance_price[0].text
# Out:
# '200 ₽'

# %% [markdown]
# ___

# %% [markdown]
# Кол-во имеющихся билетов и стоимость

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
#from webdriver_manager.chrome import ChromeDriverManager

br = webdriver.Chrome()

# %%
# открываем страницу в Chrome в автоматическом режиме
br.get("https://bolshoi.ru/timetable/all")
time.sleep(2)

# %%
field = br.find_element(By.XPATH, '//*[@id="main-content"]/div[2]/div/div[2]/span/div[3]/div[2]/div[1]/div/a')

# %%
# нажали на нее
field.click()
time.sleep(2)

# %%
# сохраним код html страницы
page_add = br.page_source
soup_add = BeautifulSoup(page_add, 'html')
soup_add
# Out:
# <html dir="ltr" lang="ru-RU" style="--scrollbar-width: 17px;"><head>
# ...

# %%
performance_tickets = soup_add.find_all('div', {'class': 'PerformanceScheduleItem-tickets'})
performance_tickets
# Out:
# [<div class="PerformanceScheduleItem-tickets isHidden" data-v-2d0c6fc3="">0</div>,
#  <div class="PerformanceScheduleItem-tickets" data-v-2d0c6fc3="">40 билетов</div>,
#  <div class="PerformanceScheduleItem-tickets" data-v-2d0c6fc3="">35 билетов</div>,
#  <div class="PerformanceScheduleItem-tickets" data-v-2d0c6fc3="">67 билетов</div>]

# %%
performance_price = soup_add.find_all('div', {'class': 'PerformanceScheduleItem-price'})
performance_price
# Out:
# [<div class="PerformanceScheduleItem-price isHidden" data-v-2d0c6fc3=""><span data-v-2d0c6fc3="">0</span></div>,
#  <div class="PerformanceScheduleItem-price" data-v-2d0c6fc3=""><span data-v-2d0c6fc3="">200 ₽</span></div>,
#  <div class="PerformanceScheduleItem-price" data-v-2d0c6fc3=""><span data-v-2d0c6fc3="">200 ₽</span></div>,
#  <div class="PerformanceScheduleItem-price" data-v-2d0c6fc3=""><span data-v-2d0c6fc3="">200 ₽</span></div>]

# %%
br.close()
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 br.close()
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.close(self)
#     450 def close(self) -> None:
#     451     """Closes the current window.
#     452
#     453     :Usage:
#    (...)
#     456             driver.close()
#     457     """
# --> 458     self.execute(Command.CLOSE)
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# ...
